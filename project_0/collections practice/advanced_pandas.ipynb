# %%
import pandas as pd

melb_df = pd.read_csv('data/melb_data_fe.csv')
melb_df.head()
# Out:
#        Suburb  Rooms   Type      Price Method SellerG        Date  Distance  \
# 0  Abbotsford      2  house  1480000.0      S  Biggin  2016-03-12       2.5
# 1  Abbotsford      2  house  1035000.0      S  Biggin  2016-04-02       2.5
# 2  Abbotsford      3  house  1465000.0     SP  Biggin  2017-04-03       2.5
# 3  Abbotsford      3  house   850000.0     PI  Biggin  2017-04-03       2.5
# 4  Abbotsford      4  house  1600000.0     VB  Nelson  2016-04-06       2.5
#
#    Postcode  Bedroom  ...  Longtitude             Regionname  Propertycount  \
# 0      3067        2  ...    144.9984  Northern Metropolitan           4019
# 1      3067        2  ...    144.9934  Northern Metropolitan           4019
# 2      3067        3  ...    144.9944  Northern Metropolitan           4019
# 3      3067        3  ...    144.9969  Northern Metropolitan           4019
# 4      3067        3  ...    144.9941  Northern Metropolitan           4019
#
# ...

# %%
melb_df['Date'] = pd.to_datetime(melb_df['Date'])
# print(melb_df['Date'])
quarter_sold = melb_df['Date'].dt.quarter
quarter_sold.value_counts().iloc[1]
# Out:
# 4359

# %%
melb_df.columns

unique_list = []

for col in melb_df.columns:
    item = (col, melb_df[col].nunique(), melb_df[col].dtype)
    unique_list.append(item)
    
unique_counts = pd.DataFrame(
    unique_list,
    columns = ['Column Name', 'Num Unique', 'Type']).sort_values(by = 'Num Unique', ignore_index=True)

print(unique_counts)
# Out:
#         Column Name  Num Unique            Type
# 0           Weekend           2           int64
# 1              Type           3          object
# 2            Method           5          object
# 3       WeekdaySale           7           int64
# 4        Regionname           8          object
# 5             Rooms           9           int64
# 6          Bathroom           9           int64
# 7               Car          11           int64
# 8        StreetType          11          object
# 9         MonthSale          12           int64
# 10          Bedroom          12           int64
# 11      CouncilArea          33          object
# 12          SellerG          50          object
# 13             Date          58  datetime64[ns]
# 14           Suburb         120          object
# 15      AgeBuilding         152           int64
# 16         Postcode         198           int64
# 17         Distance         202         float64
# 18    Propertycount         311           int64
# ...

# %%
black_list = ['Date', 'Rooms', 'Bedroom', 'Bathroom', 'Car']
max_unique_counts = 150

for col in melb_df.columns:
    if melb_df[col].nunique() < max_unique_counts and col not in black_list:
        melb_df[col] = melb_df[col].astype('category')
        

melb_df.info()
print(melb_df.dtypes.count())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13580 entries, 0 to 13579
# Data columns (total 26 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Suburb           13580 non-null  category
#  1   Rooms            13580 non-null  int64
#  2   Type             13580 non-null  category
#  3   Price            13580 non-null  float64
#  4   Method           13580 non-null  category
#  5   SellerG          13580 non-null  category
#  6   Date             13580 non-null  datetime64[ns]
#  7   Distance         13580 non-null  float64
#  8   Postcode         13580 non-null  int64
#  9   Bedroom          13580 non-null  int64
#  10  Bathroom         13580 non-null  int64
#  11  Car              13580 non-null  int64
#  12  Landsize         13580 non-null  float64
#  13  BuildingArea     13580 non-null  float64
#  14  CouncilArea      12211 non-null  category
#  15  Lattitude        13580 non-null  float64
# ...

# %%
melb_df.sort_values(by='Date', ascending=False)
melb_df.sort_values(by=['Price', 'Distance']).loc[::10, ['Distance', 'Price']]
# Out:
#        Distance      Price
# 2652        6.4    85000.0
# 7116        7.8   200000.0
# 5206       11.2   220000.0
# 7240        8.2   241000.0
# 2898       13.0   250000.0
# ...         ...        ...
# 13341       6.3  4060000.0
# 8591        1.5  4275000.0
# 1094       11.2  4700000.0
# 5801        6.1  5046000.0
# 251         6.3  5525000.0
#
# [1358 rows x 2 columns]

# %%
mask1 = melb_df['AreaRatio'] <= -0.8
mask2 = melb_df['Type'] == 'townhouse'
mask3 = melb_df['SellerG'] == 'McGrath'

melb_df[mask1 & mask2 & mask3].sort_values(
    by=['Date', 'AreaRatio'],
    ascending=[True, False],
    ignore_index=True
).loc[:, ['Date', 'AreaRatio']]
# Out:
#         Date  AreaRatio
# 0 2016-07-26  -0.974922
# 1 2016-09-24  -0.971831
# 2 2016-11-27  -0.953608
# 3 2016-12-11  -0.945946
# 4 2017-08-04  -0.947368
# 5 2017-08-04  -0.970874

# %%
melb_df.sort_values(by=['AreaRatio'], ascending=False, ignore_index=True).iloc[1558]
# Out:
# Suburb                       Elsternwick
# Rooms                                  2
# Type                               house
# Price                           716000.0
# Method                                 S
# SellerG                    hockingstuart
# Date                 2017-03-06 00:00:00
# Distance                             7.2
# Postcode                            3185
# Bedroom                                2
# Bathroom                               1
# Car                                    1
# Landsize                             0.0
# BuildingArea                       126.0
# CouncilArea                    Glen Eira
# Lattitude                      -37.89438
# Longtitude                     145.00851
# Regionname         Southern Metropolitan
# Propertycount                       4898
# MeanRoomsSquare                     25.2
# AreaRatio                            1.0
# MonthSale                              3
# AgeBuilding                           47
# ...

# %%
melb_df[(melb_df['Type'] == 'townhouse') & (melb_df['Rooms'] > 2)].sort_values(by=['Rooms', 'MeanRoomsSquare'], ascending=[True, False], ignore_index=True).iloc[18]

# %%
melb_df.groupby(by='Type')['Price'].mean()
melb_df.groupby(by='Regionname')['Distance'].min().sort_values(ascending=False)
melb_df.groupby(by='MonthSale')['Price'].agg(
    ['count', 'mean', 'max']
).sort_values(by='count', ascending=False)

melb_df.groupby(by='Regionname')['SellerG'].agg(['nunique', set])
# Out:
#                             nunique  \
# Regionname
# Eastern Metropolitan             26
# Eastern Victoria                 11
# Northern Metropolitan            40
# Northern Victoria                11
# South-Eastern Metropolitan       25
# Southern Metropolitan            38
# Western Metropolitan             34
# Western Victoria                  6
#
#                                                                           set
# Regionname
# Eastern Metropolitan        {hockingstuart, Fletchers, Love, C21, Philip, ...
# Eastern Victoria            {hockingstuart, Harcourts, other, Fletchers, M...
# Northern Metropolitan       {hockingstuart, McDonald, Love, Fletchers, C21...
# Northern Victoria           {McDonald, Raine, hockingstuart, YPA, Buckingh...
# South-Eastern Metropolitan  {hockingstuart, Fletchers, C21, Noel, O'Brien,...
# Southern Metropolitan       {hockingstuart, Fletchers, C21, Philip, Nick, ...
# ...

# %%
melb_df.groupby(by='Rooms')['Price'].mean().sort_values(ascending=False)
melb_df.groupby(by='Regionname')['Lattitude'].min().sort_values()

melb_df['Date']
date1 = pd.to_datetime('2017-05-01')
date2 = pd.to_datetime('2017-10-01')
dates_range = (melb_df['Date'] >= date1) & (melb_df['Date'] < date2)

melb_df[dates_range].groupby(by='SellerG')['Price'].sum().sort_values(ascending=True)

# %%
melb_df.groupby(['Rooms', 'Type'])['Price'].mean().unstack()

melb_df.pivot_table(
    values = 'Price',
    index = 'Rooms',
    columns = 'Type'
).round()

# %%
melb_df.pivot_table(
    values = 'Price',
    index = 'Regionname', 
    columns = 'Weekend',
    aggfunc='count'
)

melb_df.pivot_table(
    values='Landsize',
    index='Regionname',
    columns='Type',
    aggfunc=['median', 'mean'],
    fill_value=0
    
).round()

melb_df.pivot_table(
    values='Price',
    index=['Method', 'Type'],
    columns='Regionname',
    aggfunc='median',
    fill_value=0
).round()

# %%
pivot = melb_df.pivot_table(
    values='Landsize',
    index='Regionname',
    columns='Type',
    aggfunc=['median', 'mean'],
    fill_value=0
)

pivot.columns
pivot['mean']['unit']

mask = pivot['mean']['house'] < pivot['median']['house']
filtered_pivot = pivot[mask]
filtered_pivot
print(list(filtered_pivot.index))
# Out:
# ['Southern Metropolitan', 'Western Metropolitan']

# %%
melb_df.pivot_table(
    values='BuildingArea',
    index='Rooms',
    columns='Type', 
    aggfunc='median',
    fill_value=0
)

melb_df.pivot_table(
    values='Price', 
    index='SellerG', 
    columns='Type', 
    aggfunc='mean',
    fill_value=0
).round().sort_values(by='unit', ascending=False)
